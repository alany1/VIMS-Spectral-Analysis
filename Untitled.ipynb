# %%
import sys
sys.path.insert(1, './scripts')

from libraries import *

# %%
belet = glob.glob('new_pixels/belet/*.pkl')

# %%
with open(belet[3], 'rb') as f:
    x = pickle.load(f)

# %%
x['second-stefan_spectrum'] - x['stefan_spectrum']
x
# Out:
# {'name': 'V1717755608_1.ir_rc20final.cub',
#  'sequenceid': 'S73',
#  'observationid': 'VIMS_167TI_FIRNADCMP002',
#  'latitude': -10.203198054119,
#  'longitude': 110.41241992407,
#  'phase': 28.320488928088,
#  'incidence': 46.849993624297,
#  'emission': 41.268447639767,
#  'distance': 187464.01318483,
#  'lineres': 113070.15130277,
#  'sampres': 102519.49168473,
#  'scposx': -160887.7829827,
#  'scposy': 85690.291408558,
#  'scposz': -43761.301221392,
#  'sunposx': -1224213902.9567,
#  'sunposy': 694860079.89401,
#  'sunposz': 370536430.65025,
#  'ettime': 392333741.06418,
#  'starttime': '2012-06-07 09:28:05.219',
#  'exposureduration': 160.0,
#  'spectrum': array([ 0.0596593 ,  0.0997691 ,  0.137383  ,  0.141244  ,  0.103132  ,
#          0.0696651 ,  0.0572986 ,  0.0546822 ,  0.068894  ,  0.0919783 ,
#          0.117229  ,  0.131007  ,  0.110121  ,  0.0687689 ,  0.0363332 ,
#          0.0287743 ,  0.0191166 ,  0.0222485 ,  0.028474  ,  0.0425363 ,
# ...
