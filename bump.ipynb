# %%
powerlaw
# Out:
# <function functions.powerlaw(x, a, k, c)>

# %%
import sys
sys.path.insert(1, './scripts')

from libraries import *
from functions import *
from fitting import *
from util import *

# %matplotlib qt
data[0]
# Out:
# /home/alanyu/anaconda3/lib/python3.8/site-packages/pysis/env.py:33: RuntimeWarning: Could not find isis. Is `ISISROOT` set?
#   warnings.warn('Could not find isis. Is `ISISROOT` set?', RuntimeWarning)
# Current progress: 50000
# Current progress: 100000
# Current progress: 150000
# Current progress: 200000
# Current progress: 250000
# DONE
# {'name': 'V1649180633_1.ir_rc20final.cub',
#  'sequenceid': 'S59',
#  'observationid': 'VIMS_129TI_REGMAP001_ISS',
#  'latitude': 6.527894053385,
#  'longitude': 117.23227585525,
#  'phase': 4.35186034428,
#  'incidence': 71.368914431631,
#  'emission': 72.074559422824,
#  'distance': 25208.69808185,
#  'lineres': 38679.377390385,
#  'sampres': 12885.433750399,
#  'scposx': 15904.022205055,
#  'scposy': 19558.581460496,
#  'scposz': 49.274092100503,
#  'sunposx': 993649050.83181,
#  'sunposy': 1013825175.7289,
#  'sunposz': 93586120.333315,
#  'ettime': 323758866.57842,
#  'starttime': '2010-04-05 16:59:19.48',
#  'exposureduration': 220.0,
#  'spectrum': array([ 0.0763505 ,  0.113136  ,  0.138922  ,  0.146524  ,  0.126     ,
#          0.0936954 ,  0.0795553 ,  0.0763359 ,  0.0885651 ,  0.111927  ,
#          0.131274  ,  0.140332  ,  0.13276   ,  0.100027  ,  0.0593369 ,
#          0.0431969 ,  0.0295527 ,  0.0313845 ,  0.042422  ,  0.0622391 ,
#          0.0827431 ,  0.0844537 ,  0.0981416 ,  0.109633  ,  0.124524  ,
#          0.0986692 ,  0.0649221 ,  0.046782  ,  0.0333819 ,  0.0279256 ,
#          0.0251519 ,  0.0251015 ,  0.0311578 ,  0.0397409 ,  0.046074  ,
#          0.0519955 ,  0.0599261 ,  0.0705508 ,  0.0756816 ,  0.0824274 ,
#          0.0849288 ,  0.0843681 ,  0.0910672 ,  0.0900338 ,  0.0759746 ,
#          0.0561447 ,  0.0431159 ,  0.029171  ,  0.0267057 ,  0.0200695 ,
#          0.0187427 ,  0.0184399 ,  0.0240378 ,  0.0220268 ,  0.0189923 ,
#          0.0214212 ,  0.0293037 ,  0.0326464 ,  0.0306571 ,  0.036423  ,
#          0.0447716 ,  0.0463914 ,  0.0401177 ,  0.0389254 ,  0.0412627 ,
#          0.0458172 ,  0.0524996 ,  0.0612893 ,  0.067655  ,  0.0680157 ,
#          0.0668292 ,  0.0634374 ,  0.0581618 ,  0.053786  ,  0.0497759 ,
#          0.0456458 ,  0.0370858 ,  0.0262122 ,  0.0201423 ,  0.0196605 ,
#          0.01502   ,  0.0145993 ,  0.0104222 ,  0.00829816,  0.00766398,
#          0.00582945,  0.00639436,  0.00664585,  0.00641143,  0.00662191,
#          0.00615382,  0.00789756,  0.00959572,  0.00899337,  0.0100685 ,
#          0.0135312 ,  0.0175461 ,  0.0192299 ,  0.019437  ,  0.0183067 ,
#          0.0178244 ,  0.0142984 ,  0.0128011 ,  0.0118281 ,  0.0146115 ,
#          0.018974  ,  0.0229973 ,  0.0251962 ,  0.0268029 ,  0.0278835 ,
#     'e': 1.3002809924450223,
#     'w': 0.05357113821693465,
#     'a': -2.424994006122228,
#     'peak_channel': 1.27813,
#     'peak_value': 0.14122852644621056,
#     'peak_channel_inferred': 1.2730494809480948,
#     'peak_value_inferred': 0.14308039405427408},
#    'raw_peak_channel': 1.27813,
#    'raw_peak_value': 0.15001068533991868},
#   '1.6': {'gaussian': {'mean': 1.5521851190197442,
#     'sigma': 0.06245641870534074,
#     'amp': 0.11475356228432658},
#    'skew': {'A': 0.018232530119924144,
#     'e': 1.6159181533571798,
#     'w': 0.09945399335502701,
#     'a': -2.6021154545982776,
#     'peak_channel': 1.57361,
#     'peak_value': 0.11569291790238691,
#     'peak_channel_inferred': 1.5664143514351434,
#     'peak_value_inferred': 0.11661447119020474},
#    'raw_peak_channel': 1.57361,
#    'raw_peak_value': 0.11522918721086597},
#   '2.0': {'gaussian': {'mean': 2.0185770811537957,
#     'sigma': 0.09197723466768977,
#     'amp': 0.08746872757038059},
#    'skew': {'A': 0.021776209308778244,
#     'e': 2.116784505669185,
#     'w': 0.16623849315013234,
#     'a': -3.0724566132602003,
#     'peak_channel': 2.03424,
#     'peak_value': 0.08652364720994395,
#     'peak_channel_inferred': 2.0388213641364135,
#     'peak_value_inferred': 0.08662931104980391},
#    'raw_peak_channel': 2.01781,
#    'raw_peak_value': 0.09225675921686172},
#   '1.0': {'gaussian': {'mean': 1.0620170267942843,
#     'sigma': 0.02976224131191652,
#     'amp': 0.15567167748645014},
#    'skew': {'A': -0.01201750748520105,
#     'e': 1.094061135958611,
#     'w': -0.05000342705669171,
#     'a': 2.803288213687809,
#     'peak_channel': 1.06541,
#     'peak_value': 0.15392293038785307,
#     'peak_channel_inferred': 1.0697977497749775,
#     'peak_value_inferred': 0.15565283190933127},
#    'raw_peak_channel': 1.06541,
#    'raw_peak_value': 0.1478645999646316},
#   'powerlaw': {'scale': 0.10209196025734209, 'exponent': -2.148357483732432}},
#  'stefan_fit': {'1.2': {'gaussian': {'mean': 1.2584093273699917,
#     'sigma': 0.06288846696480599,
#     'amp': 0.18079989908602648},
#    'skew': {'A': 0.027204230909624726,
#     'e': 1.3148331775001103,
#     'w': 0.09862683298711558,
#     'a': -3.941073283337431,
#     'peak_channel': 1.27813,
#     'peak_value': 0.190727624970757,
#     'peak_channel_inferred': 1.2734116171617162,
#     'peak_value_inferred': 0.19163993754873895},
#    'raw_peak_channel': 1.27813,
#    'raw_peak_value': 0.2102708456082373},
#   '1.6': {'gaussian': {'mean': 1.5465528359187624,
#     'sigma': 0.09196903075899181,
#     'amp': 0.14554226031445006},
#    'skew': {'A': 0.03356010265855381,
#     'e': 1.4821176243805712,
#     'w': 0.11620425621810845,
#     'a': 1.1469511584751222,
#     'peak_channel': 1.54035,
#     'peak_value': 0.1457792344071003,
#     'peak_channel_inferred': 1.5431459595959596,
#     'peak_value_inferred': 0.14584898266351923},
#    'raw_peak_channel': 1.57361,
#    'raw_peak_value': 0.1537757954384253},
#   '2.0': {'gaussian': {'mean': 2.0119245094224367,
#     'sigma': 0.11701046457815266,
#     'amp': 0.10710852008964178},
#    'skew': {'A': 0.03437373332236088,
#     'e': 2.1306809423532775,
#     'w': 0.20706573526406777,
#     'a': -2.623851739565092,
#     'peak_channel': 2.03424,
#     'peak_value': 0.10566542646468018,
#     'peak_channel_inferred': 2.0279157535753574,
#     'peak_value_inferred': 0.10581282662892448},
#    'raw_peak_channel': 2.01781,
#    'raw_peak_value': 0.11485110302942554},
#   '1.0': {'gaussian': {'mean': 1.0582273999972382,
#     'sigma': 0.049895073382770834,
#     'amp': 0.23116515561761358},
#    'skew': {'A': -0.029206092253511968,
#     'e': 1.0897420623056866,
#     'w': -0.061008727459075526,
#     'a': 0.9607967946884685,
#     'peak_channel': 1.06541,
#     'peak_value': 0.2290169352800807,
#     'peak_channel_inferred': 1.0592905790579057,
#     'peak_value_inferred': 0.23074169315163431},
#    'raw_peak_channel': 1.06541,
#    'raw_peak_value': 0.2369641860677071}},
#  'regular_fit': {'1.2': {'gaussian': {'mean': 1.2655028508318156,
#     'sigma': 0.036827873268681005,
#     'amp': 0.08070635069705588},
#    'skew': {'A': 0.007264433516058163,
#     'e': 1.300280986169227,
#     'w': 0.053571085856477185,
#     'a': -2.4250002285780785,
#     'peak_channel': 1.27813,
#     'peak_value': 0.0836366943308225,
#     'peak_channel_inferred': 1.2730494809480948,
#     'peak_value_inferred': 0.08473337233283237},
#    'raw_peak_channel': 1.27813,
#    'raw_peak_value': 0.08883747190802153},
#   '1.6': {'gaussian': {'mean': 1.5521853363958413,
#     'sigma': 0.062456742709753,
#     'amp': 0.0679577632567816},
#    'skew': {'A': 0.010797443249000395,
#     'e': 1.615917974263889,
#     'w': 0.09945376433542634,
#     'a': -2.602089092341689,
#     'peak_channel': 1.57361,
#     'peak_value': 0.06851418073900482,
#     'peak_channel_inferred': 1.5664143514351434,
#     'peak_value_inferred': 0.06905996419846953},
#    'raw_peak_channel': 1.57361,
#    'raw_peak_value': 0.06823960430000413},
#   '2.0': {'gaussian': {'mean': 2.0185767743127156,
#     'sigma': 0.09197717537291425,
#     'amp': 0.051799667161859825},
#    'skew': {'A': 0.012896041179915359,
#     'e': 2.116784640813729,
#     'w': 0.16623876331605483,
#     'a': -3.0724756455860938,
#     'peak_channel': 2.03424,
#     'peak_value': 0.051239960576635574,
#     'peak_channel_inferred': 2.0388213641364135,
#     'peak_value_inferred': 0.05130254094487694},
#    'raw_peak_channel': 2.01781,
#    'raw_peak_value': 0.05463515757161215},
#   '1.0': {'gaussian': {'mean': 1.0620170241654334,
#     'sigma': 0.029762234615670183,
#     'amp': 0.09218996210569973},
#    'skew': {'A': 0.007116864339987322,
#     'e': 1.0940611399416973,
#     'w': 0.05000340822338852,
#     'a': -2.803264670654008,
#     'peak_channel': 1.06541,
#     'peak_value': 0.09115427908396796,
#     'peak_channel_inferred': 1.0697977497749775,
#     'peak_value_inferred': 0.09217870805866775},
#    'raw_peak_channel': 1.06541,
#    'raw_peak_value': 0.08756654180756858},
#   'powerlaw': {'scale': 0.060459642366325235, 'exponent': -2.148357630334561}},
#  'second-stefan_spectrum': array([ 0.12892522,  0.1910411 ,  0.23458326,  0.24741998,  0.21276321,
#          0.15821377,  0.13433684,  0.12890057,  0.14955076,  0.11715414,
#          0.14982342,  0.16511873,  0.15233268,  0.09705983,  0.02835065,
#         -0.11285687, -0.06405097, -0.0609578 , -0.04231991, -0.00885682,
#          0.01914464,  0.02189705,  0.01962673,  0.01368883,  0.02060038,
#          0.0191752 ,  0.01921454,  0.02709624,  0.0265721 ,  0.04040661,
#          0.0382658 ,  0.03004436,  0.03050873,  0.01312994,  0.02922691,
#          0.03326536,  0.02643786,  0.02809234,  0.02213616,  0.02027988,
#          0.0141611 ]),
#  'stefan-second_fit': {'1.2': {'gaussian': {'mean': 1.4988061852721164,
#     'sigma': 0.010047277618550728,
#     'amp': -0.03777511187008859},
#    'skew': {'A': 0.005191415732226431,
#     'e': 1.294693500881145,
#     'w': 0.0386926061621545,
#     'a': -8.900548409812968,
#     'peak_channel': 1.27813,
#     'peak_value': 0.09767312870378393,
#     'peak_channel_inferred': 1.2847121392139214,
#     'peak_value_inferred': 0.1024272342452636},
#    'raw_peak_channel': 1.27813,
#    'raw_peak_value': 0.09631727406841953},
#   '1.6': {'gaussian': {'mean': 1.4987254093075482,
#     'sigma': 0.004669334794768488,
#     'amp': -0.04845704464192644},
#    'skew': {'A': -0.0013761839651661738,
#     'e': 1.641807723427309,
#     'w': 0.01563032666638362,
#     'a': -88.89442071593417,
#     'peak_channel': 1.49169,
#     'peak_value': -6.555311427525772e-22,
#     'peak_channel_inferred': 1.6432882718271826,
#     'peak_value_inferred': -0.0},
#    'raw_peak_channel': 1.57361,
#    'raw_peak_value': 0.019063854212152315},
#   '2.0': {'gaussian': {'mean': 2.0216947751456082,
#     'sigma': 0.025860731000975978,
#     'amp': 0.027512444575504513},
#    'skew': {'A': 0.0017915998677852474,
#     'e': 1.9956681325433503,
#     'w': 0.03829381724483964,
#     'a': 2.0521579936608085,
#     'peak_channel': 2.01781,
#     'peak_value': 0.027865833259194336,
#     'peak_channel_inferred': 2.015899194919492,
#     'peak_value_inferred': 0.027949556135755668},
#    'raw_peak_channel': 2.01781,
#    'raw_peak_value': 0.024557712806002704},
#   '1.0': {'gaussian': {'mean': 1.0613865088856789,
#     'sigma': 0.027286044013187436,
#     'amp': 0.1826165865090376},
#    'skew': {'A': 4.711639755903831,
#     'e': 1.1029511102414957,
#     'w': 25.729388467400636,
#     'a': -2660.005749094107,
#     'peak_channel': 1.04755,
#     'peak_value': 0.14611058043882177,
#     'peak_channel_inferred': 1.053222512251225,
#     'peak_value_inferred': 0.1461106270434968},
#    'raw_peak_channel': 1.06541,
#    'raw_peak_value': 0.16511873115571513}},
#  'bump_info': {'bump': array([-1.22359303e-03,  1.40026065e-03,  2.13670565e-03,  3.68995124e-03,
#           5.57641879e-03,  7.33927767e-03,  4.80575735e-03, -1.66758699e-06,
#          -1.75000038e-04]),
#   'bump_max': 0.007339277665487073,
#   'polyfit': array([-0.36086705,  0.80214297]),
#   'bump_max_channel': 75}}

# %%
#plt.plot(vims_wave, data[0]['spectrum'])

#plt.plot(vims_wave[70:74], data[0]['spectrum'][70:74])
#plt.plot(vims_wave[76:80], data[0]['spectrum'][76:80], color = 'r')

#plt.plot(vims_wave, data[0]['spectrum'] - powerlaw_no_constant(vims_wave,data[0]['regular_fit']['powerlaw']['scale'], data[0]['regular_fit']['powerlaw']['exponent']), label = 'spectra with powerlaw')
#plt.plot(vims_wave, data[0]['second-stefan_spectrum'], label = 'second stefan')
#plt.plot(vims_wave, data[0]['stefan_spectrum'], label = 'stefan')

#plt.legend()

def airmass(incidence, emission):
    return np.cos(np.radians(incidence))/(np.cos(np.radians(incidence)) + np.cos(np.radians(emission)))#1/(np.cos(np.radians(incidence))) + 1/(np.cos(np.radians(emission)))

incidences = []
emission = []
spec = []
peaks = []
air = []
for i,pixel in enumerate(data):
    if (not 0 < pixel['spectrum'][72] < 1) or pixel['incidence'] > 70 or pixel['emission'] > 70: continue
    #incidences.append(pixel['incidence'])
    #emission.append(pixel['emission'])
    
    try:
        
        peaks.append(pixel['bump_info']['bump_max'])
        spec.append(pixel['spectrum'][72])
        air.append(airmass(pixel['incidence'], pixel['emission']))
    except:
        pass
#air = airmass(incidences, emission)

plt.ylim([0, .05])
print(len(spec), len(peaks), len(air))
plt.scatter(air, peaks)

#plt.plot(np.append(vims_wave[70:74],vims_wave[76:80]), np.append(data[0]['spectrum'][70:74],data[0]['spectrum'][76:80]))
# Out:
# 236236 236236 236236

# %%
def bump_test(i):
    fig,axs = plt.subplots(2)
    b = examine_bump(data[i]['spectrum'])
    print(b)
    axs[0].plot(vims_wave[70:79], b['bump'])
    axs[1].plot(vims_wave, data[i]['spectrum'])
bump_test(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c1a3f32c323f> in <module>
#       5     axs[0].plot(vims_wave[70:79], b['bump'])
#       6     axs[1].plot(vims_wave, data[i]['spectrum'])
# ----> 7 bump_test(0)
#
# <ipython-input-5-c1a3f32c323f> in bump_test(i)
#       1 def bump_test(i):
#       2     fig,axs = plt.subplots(2)
# ----> 3     b = examine_bump(data[i]['spectrum'])
#       4     print(b)
#       5     axs[0].plot(vims_wave[70:79], b['bump'])
#
# TypeError: examine_bump() missing 2 required positional arguments: 'start' and 'end'

# %%
def examine_bump(i, start, end):
    fig, axs = plt.subplots(2,2)
    
    spectrum = data[i]['spectrum']
    p = np.polyfit(np.append(vims_wave[start[0]:start[1]],vims_wave[end[0]:end[1]]), np.append(spectrum[start[0]:start[1]],spectrum[end[0]:end[1]]), 1)
    fit = np.polyval(p, np.append(vims_wave[start[0]:start[1]], vims_wave[end[0]:end[1]]))
    
    axs[0,0].plot(np.append(vims_wave[start[0]:start[1]],vims_wave[end[0]:end[1]]), fit, label = 'Linear fit')
    axs[0,0].plot(vims_wave[start[0]:end[1]], data[i]['spectrum'][start[0]:end[1]], label = 'Spectra')
    axs[0,0].plot(vims_wave[60:85], spectrum[60:85])
    axs[0,0].plot(vims_wave[start[0]:start[1]], spectrum[start[0]:start[1]], color = 'r')
    axs[0,0].plot(vims_wave[end[0]:end[1]], spectrum[end[0]:end[1]], color = 'r')
    
    axs[0,1].plot(vims_wave[start[0]:end[1]], np.append(np.append(spectrum[start[0]:start[1]]-fit[:start[1]-start[0]],
                                                                  spectrum[start[1]:end[0]]-np.polyval(p, vims_wave[start[1]:end[0]])), 
                                                                  spectrum[end[0]:end[1]]-fit[start[1]-start[0]:]))
    axs[1,0].plot(vims_wave[60:85], data[i]['spectrum'][60:85])
    axs[1,0].plot(vims_wave[start[1]:end[0]], spectrum[start[1]:end[0]])
    
    axs[1,1].plot(vims_wave,spectrum)
    plt.legend()
    print(np.max(data[i]['spectrum']))
    
examine_bump(0, (70,72), (77,79))
# Out:
# No handles with labels found to put in legend.
# 0.146524
